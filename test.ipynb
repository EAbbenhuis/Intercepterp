# %%
import sys
sys.path.insert(0, '/kaggle/working/intercepterp/intercepterp/intercepterp')

from envs.intercept_env import InterceptEnv
import inspect

# Find ActionConfig
import envs.intercept_env as ie
print([x for x in dir(ie) if 'Action' in x])

# Also check where it's imported from
import training.train as tr
print(inspect.getfile(tr))
print([x for x in dir(tr) if 'Action' in x])
# Out:
# (self, config: 'dict', action_config: 'ActionConfig', curriculum_stage: 'int' = 1, render_mode: 'str | None' = None, rng_seed: 'int | None' = None) -> 'None'
